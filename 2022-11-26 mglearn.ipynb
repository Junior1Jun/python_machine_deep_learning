# %%
# mglearn : 그래프나 데이터 적재와 관련한 세세한 코드를 일일이 쓰지 않아도 되게끔 해주는, 유틸리티 함수들을 포함하는 라이브러리
pip install mglearn
# Out:
# Collecting mglearn
#   Downloading mglearn-0.1.9.tar.gz (540 kB)
#      -------------------------------------- 540.1/540.1 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\gram\anaconda3\lib\site-packages (from mglearn) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\gram\anaconda3\lib\site-packages (from mglearn) (3.5.2)
# Requirement already satisfied: scikit-learn in c:\users\gram\anaconda3\lib\site-packages (from mglearn) (1.0.2)
# Requirement already satisfied: pandas in c:\users\gram\anaconda3\lib\site-packages (from mglearn) (1.4.4)
# Requirement already satisfied: pillow in c:\users\gram\anaconda3\lib\site-packages (from mglearn) (9.2.0)
# Requirement already satisfied: cycler in c:\users\gram\anaconda3\lib\site-packages (from mglearn) (0.11.0)
# Requirement already satisfied: imageio in c:\users\gram\anaconda3\lib\site-packages (from mglearn) (2.19.3)
# Requirement already satisfied: joblib in c:\users\gram\anaconda3\lib\site-packages (from mglearn) (1.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gram\anaconda3\lib\site-packages (from matplotlib->mglearn) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gram\anaconda3\lib\site-packages (from matplotlib->mglearn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gram\anaconda3\lib\site-packages (from matplotlib->mglearn) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\gram\anaconda3\lib\site-packages (from matplotlib->mglearn) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\gram\anaconda3\lib\site-packages (from matplotlib->mglearn) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gram\anaconda3\lib\site-packages (from pandas->mglearn) (2022.1)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\gram\anaconda3\lib\site-packages (from scikit-learn->mglearn) (1.9.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gram\anaconda3\lib\site-packages (from scikit-learn->mglearn) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\gram\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->mglearn) (1.16.0)
# Building wheels for collected packages: mglearn
#   Building wheel for mglearn (setup.py): started
#   Building wheel for mglearn (setup.py): finished with status 'done'
#   Created wheel for mglearn: filename=mglearn-0.1.9-py2.py3-none-any.whl size=582621 sha256=5447a869cd20468e8f2c91fab92ce8415406ca82b1c78be06c2f6ab7cfb8573b
#   Stored in directory: c:\users\gram\appdata\local\pip\cache\wheels\df\30\8a\1e2c8f144c9d411b0688f628d496d2db8f61b6d14bcedaa1df
# Successfully built mglearn
# Installing collected packages: mglearn
# Successfully installed mglearn-0.1.9
# Note: you may need to restart the kernel to use updated packages.

# %%
import mglearn
import matplotlib.pyplot as plt

# %%
# mglearn.datasets의 make_forge() 함수를 사용하여, forge 데이터셋을 불러오고 변수 X , Y에 저장함.
X, Y = mglearn.datasets.make_forge()

# %%
mglearn.discrete_scatter(X[:,0],X[:,1],Y)
# X[:,0]와 Y간의 산점도와  //  X[:,1]와 Y간의 산점도를 그려줍니다.

plt.legend(["class 0","class 1"], loc = 4)
plt.xlabel("first feature")
plt.ylabel("second feature")
print("X shape : ",X.shape)
# Out:
# X shape :  (26, 2)

# %%
X, Y = mglearn.datasets.make_wave(n_samples = 40)
plt.plot(X, Y ,'o')
plt.ylim(-3, 3)
plt.xlabel("feature")
plt.ylabel("target")
plt.show()
